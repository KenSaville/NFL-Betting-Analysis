# %%
#NFL-Betting-Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
spreaddata = pd.read_csv('Documents\Bootcamp\Project1\spreadspoke_scores.csv')

# %%
spreaddata
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 12929      1/3/2021             2020            17             False
# 12930      1/3/2021             2020            17             False
# 12931      1/3/2021             2020            17             False
# 12932      1/3/2021             2020            17             False
# 12933      1/3/2021             2020            17             False
#
#                   team_home  score_home  score_away                 team_away  \
# ...

# %%
necessary_spreaddata_df = pd.DataFrame(spreaddata, columns=["schedule_season", "schedule_week", "schedule_playoff", "team_home", "score_home", "score_away", "team_away", "team_favorite_id", "spread_favorite", "over_under_line", "weather_temperature"])
necessary_spreaddata_df
# Out:
#        schedule_season schedule_week  schedule_playoff             team_home  \
# 0                 1966             1             False        Miami Dolphins
# 1                 1966             1             False        Houston Oilers
# 2                 1966             1             False    San Diego Chargers
# 3                 1966             2             False        Miami Dolphins
# 4                 1966             1             False     Green Bay Packers
# ...                ...           ...               ...                   ...
# 12929             2020            17             False  New England Patriots
# 12930             2020            17             False       New York Giants
# 12931             2020            17             False   Philadelphia Eagles
# 12932             2020            17             False   San Francisco 49ers
# 12933             2020            17             False  Tampa Bay Buccaneers
#
# ...

# %%
necessary_spreaddata_df.count()
# Out:
# schedule_season        12934
# schedule_week          12934
# schedule_playoff       12934
# team_home              12934
# score_home             12797
# score_away             12797
# team_away              12934
# team_favorite_id       10318
# spread_favorite        10318
# over_under_line        10308
# weather_temperature    12008
# dtype: int64

# %%
necessary_spreaddata_df = necessary_spreaddata_df.dropna(how='any')
necessary_spreaddata_df
# Out:
#        schedule_season schedule_week  schedule_playoff           team_home  \
# 350               1967     Superbowl              True   Green Bay Packers
# 538               1968     Superbowl              True     Baltimore Colts
# 727               1969     Superbowl              True  Kansas City Chiefs
# 916               1970     Superbowl              True     Baltimore Colts
# 1105              1971     Superbowl              True      Dallas Cowboys
# ...                ...           ...               ...                 ...
# 12770             2020             7             False   Arizona Cardinals
# 12771             2020             7             False     Atlanta Falcons
# 12774             2020             7             False      Houston Texans
# 12778             2020             7             False  New Orleans Saints
# 12790             2020             8             False       Detroit Lions
#
# ...

# %%
necessary_spreaddata_df.dtypes
# Out:
# schedule_season          int64
# schedule_week           object
# schedule_playoff          bool
# team_home               object
# score_home             float64
# score_away             float64
# team_away               object
# team_favorite_id        object
# spread_favorite        float64
# over_under_line         object
# weather_temperature    float64
# dtype: object

# %%
necessary_spreaddata_df['over_under_line'] = pd.to_numeric(necessary_spreaddata_df['over_under_line'], errors="coerce")
# Out:
# <ipython-input-9-4d6e904ce131>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   necessary_spreaddata_df['over_under_line'] = pd.to_numeric(necessary_spreaddata_df['over_under_line'], errors="coerce")

# %%
necessary_spreaddata_df.dtypes
# Out:
# schedule_season          int64
# schedule_week           object
# schedule_playoff          bool
# team_home               object
# score_home             float64
# score_away             float64
# team_away               object
# team_favorite_id        object
# spread_favorite        float64
# over_under_line        float64
# weather_temperature    float64
# dtype: object

# %%
#trying to drop playoff and Super Bowl games

#playoff_games = necessary_spreaddata_df[necessary_spreaddata_df['schedule_playoff'] == 'true'].index

#regseason_spreaddata_df = necessary_spreaddata_df.drop(playoff_games, inplace = True)
#regseason_spreaddata_df

# %%
total = (necessary_spreaddata_df['score_home'] + necessary_spreaddata_df['score_away'])
necessary_spreaddata_df['total'] = total
necessary_spreaddata_df
# Out:
# <ipython-input-12-0786863705bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   necessary_spreaddata_df['total'] = total
#        schedule_season schedule_week  schedule_playoff           team_home  \
# 350               1967     Superbowl              True   Green Bay Packers
# 538               1968     Superbowl              True     Baltimore Colts
# 727               1969     Superbowl              True  Kansas City Chiefs
# 916               1970     Superbowl              True     Baltimore Colts
# 1105              1971     Superbowl              True      Dallas Cowboys
# ...                ...           ...               ...                 ...
# 12770             2020             7             False   Arizona Cardinals
# ...

# %%
#add new columns for total score and Over or Under 

#score = necessary_spreaddata_df['total'].index()

OU = []
for x in necessary_spreaddata_df.itertuples():

#for row in necessary_spreaddata_df:   
 
    if x[12] > x[10]:
        OU.append("over")
    elif x[12] < x[10]:
        OU.append("under")
    else:
        OU.append("push")

necessary_spreaddata_df['over/under'] = OU
necessary_spreaddata_df
# Out:
# <ipython-input-37-d66d94028d01>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   necessary_spreaddata_df['over/under'] = OU
#            schedule_season schedule_week schedule_playoff           team_home  \
# 350                   1967     Superbowl             True   Green Bay Packers
# 538                   1968     Superbowl             True     Baltimore Colts
# 727                   1969     Superbowl             True  Kansas City Chiefs
# 916                   1970     Superbowl             True     Baltimore Colts
# 1105                  1971     Superbowl             True      Dallas Cowboys
# ...                    ...           ...              ...                 ...
# ...
