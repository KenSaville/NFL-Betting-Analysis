# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import os

# %%
nfl_df = pd.read_csv("raw_data/spreadspoke_scores.csv")

# %%
nfl_df.dtypes
# Out:
# schedule_date           object
# schedule_season          int64
# schedule_week           object
# schedule_playoff          bool
# team_home               object
# score_home             float64
# score_away             float64
# team_away               object
# team_favorite_id        object
# spread_favorite        float64
# over_under_line         object
# stadium                 object
# stadium_neutral           bool
# weather_temperature    float64
# weather_wind_mph       float64
# weather_humidity        object
# weather_detail          object
# dtype: object

# %%
nfl_df.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0      9/2/1966             1966             1             False
# 1      9/3/1966             1966             1             False
# 2      9/4/1966             1966             1             False
# 3      9/9/1966             1966             2             False
# 4     9/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# 1              NaN              NaN             NaN    Rice Stadium
# 2              NaN              NaN             NaN  Balboa Stadium
# 3              NaN              NaN             NaN     Orange Bowl
# 4              NaN              NaN             NaN   Lambeau Field
#
#    stadium_neutral  weather_temperature  weather_wind_mph weather_humidity  \
# 0            False                 83.0               6.0               71
# 1            False                 81.0               7.0               70
# 2            False                 70.0               7.0               82
# 3            False                 82.0              11.0               78
# 4            False                 64.0               8.0               62
#
#   weather_detail
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
nfl_df.isnull().sum()
# Out:
# schedule_date              0
# schedule_season            0
# schedule_week              0
# schedule_playoff           0
# team_home                  0
# score_home               137
# score_away               137
# team_away                  0
# team_favorite_id        2616
# spread_favorite         2616
# over_under_line         2626
# stadium                    0
# stadium_neutral            0
# weather_temperature      926
# weather_wind_mph         926
# weather_humidity        4546
# weather_detail         10223
# dtype: int64

# %%
#drop rows that don't have any scores
nfl_df_drop_scores = nfl_df.dropna(subset = ['score_home'])

# %%
nfl_df_drop_scores
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0          9/2/1966             1966             1             False
# 1          9/3/1966             1966             1             False
# 2          9/4/1966             1966             1             False
# 3          9/9/1966             1966             2             False
# 4         9/10/1966             1966             1             False
# ...             ...              ...           ...               ...
# 12792     11/1/2020             2020             8             False
# 12793     11/1/2020             2020             8             False
# 12794     11/1/2020             2020             8             False
# 12795     11/1/2020             2020             8             False
# 12796     11/2/2020             2020             8             False
#
#                  team_home  score_home  score_away             team_away  \
# 0           Miami Dolphins        14.0        23.0       Oakland Raiders
# 1           Houston Oilers        45.0         7.0        Denver Broncos
# 2       San Diego Chargers        27.0         7.0         Buffalo Bills
# 3           Miami Dolphins        14.0        19.0         New York Jets
# 4        Green Bay Packers        24.0         3.0       Baltimore Colts
# ...                    ...         ...         ...                   ...
# 12792   Kansas City Chiefs        35.0         9.0         New York Jets
# 12793       Miami Dolphins        28.0        17.0      Los Angeles Rams
# 12794  Philadelphia Eagles        23.0         9.0        Dallas Cowboys
# 12795     Seattle Seahawks        37.0        27.0   San Francisco 49ers
# 12796      New York Giants        23.0        25.0  Tampa Bay Buccaneers
#
#       team_favorite_id  spread_favorite over_under_line  \
# 0                  NaN              NaN             NaN
# 1                  NaN              NaN             NaN
# 2                  NaN              NaN             NaN
# 3                  NaN              NaN             NaN
# 4                  NaN              NaN             NaN
# ...                ...              ...             ...
# 12792               KC            -19.5              49
# 12793              LAR             -3.5            45.5
# 12794              PHI            -11.5            42.5
# 12795              SEA             -3.0            53.5
# 12796               TB            -12.5              45
#
#                        stadium  stadium_neutral  weather_temperature  \
# 0                  Orange Bowl            False                 83.0
# 1                 Rice Stadium            False                 81.0
# 2               Balboa Stadium            False                 70.0
# 3                  Orange Bowl            False                 82.0
# 4                Lambeau Field            False                 64.0
# ...                        ...              ...                  ...
# 12792        Arrowhead Stadium            False                  NaN
# 12793        Hard Rock Stadium            False                  NaN
# 12794  Lincoln Financial Field            False                  NaN
# 12795        CenturyLink Field            False                  NaN
# 12796          MetLife Stadium            False                  NaN
#
#        weather_wind_mph weather_humidity weather_detail
# 0                   6.0               71            NaN
# 1                   7.0               70            NaN
# 2                   7.0               82            NaN
# 3                  11.0               78            NaN
# 4                   8.0               62            NaN
# ...                 ...              ...            ...
# 12792               NaN              NaN            NaN
# 12793               NaN              NaN            NaN
# 12794               NaN              NaN            NaN
# 12795               NaN              NaN            NaN
# 12796               NaN              NaN            NaN
#
# [12797 rows x 17 columns]

# %%
nfl_df_drop_scores.isnull().sum()
# Out:
# schedule_date              0
# schedule_season            0
# schedule_week              0
# schedule_playoff           0
# team_home                  0
# score_home                 0
# score_away                 0
# team_away                  0
# team_favorite_id        2479
# spread_favorite         2479
# over_under_line         2489
# stadium                    0
# stadium_neutral            0
# weather_temperature      825
# weather_wind_mph         825
# weather_humidity        4409
# weather_detail         10122
# dtype: int64

# %%
#drop rows that don't have any spread_favorite
nfl_df_drop_spread = nfl_df_drop_scores.dropna(subset = ['spread_favorite'])

# %%
nfl_df_drop_spread
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 170       1/15/1967             1966     Superbowl              True
# 350       1/14/1968             1967     Superbowl              True
# 538       1/12/1969             1968     Superbowl              True
# 727       1/11/1970             1969     Superbowl              True
# 916       1/17/1971             1970     Superbowl              True
# ...             ...              ...           ...               ...
# 12792     11/1/2020             2020             8             False
# 12793     11/1/2020             2020             8             False
# 12794     11/1/2020             2020             8             False
# 12795     11/1/2020             2020             8             False
# 12796     11/2/2020             2020             8             False
#
#                  team_home  score_home  score_away             team_away  \
# 170      Green Bay Packers        35.0        10.0    Kansas City Chiefs
# 350      Green Bay Packers        33.0        14.0       Oakland Raiders
# 538        Baltimore Colts         7.0        16.0         New York Jets
# 727     Kansas City Chiefs        23.0         7.0     Minnesota Vikings
# 916        Baltimore Colts        16.0        13.0        Dallas Cowboys
# ...                    ...         ...         ...                   ...
# 12792   Kansas City Chiefs        35.0         9.0         New York Jets
# 12793       Miami Dolphins        28.0        17.0      Los Angeles Rams
# 12794  Philadelphia Eagles        23.0         9.0        Dallas Cowboys
# 12795     Seattle Seahawks        37.0        27.0   San Francisco 49ers
# 12796      New York Giants        23.0        25.0  Tampa Bay Buccaneers
#
#       team_favorite_id  spread_favorite over_under_line  \
# 170                 GB            -14.0             NaN
# 350                 GB            -13.5              43
# 538                IND            -18.0              40
# 727                MIN            -12.0              39
# 916                IND             -2.5              36
# ...                ...              ...             ...
# 12792               KC            -19.5              49
# 12793              LAR             -3.5            45.5
# 12794              PHI            -11.5            42.5
# 12795              SEA             -3.0            53.5
# 12796               TB            -12.5              45
#
#                              stadium  stadium_neutral  weather_temperature  \
# 170    Los Angeles Memorial Coliseum             True                 54.0
# 350                      Orange Bowl             True                 60.0
# 538                      Orange Bowl             True                 66.0
# 727                   Tulane Stadium             True                 55.0
# 916                      Orange Bowl             True                 59.0
# ...                              ...              ...                  ...
# 12792              Arrowhead Stadium            False                  NaN
# 12793              Hard Rock Stadium            False                  NaN
# 12794        Lincoln Financial Field            False                  NaN
# 12795              CenturyLink Field            False                  NaN
# 12796                MetLife Stadium            False                  NaN
#
#        weather_wind_mph weather_humidity weather_detail
# 170                 7.0               90            NaN
# 350                12.0               74            NaN
# 538                12.0               80            NaN
# 727                14.0               84            NaN
# 916                11.0               60            NaN
# ...                 ...              ...            ...
# 12792               NaN              NaN            NaN
# 12793               NaN              NaN            NaN
# 12794               NaN              NaN            NaN
# 12795               NaN              NaN            NaN
# 12796               NaN              NaN            NaN
#
# [10318 rows x 17 columns]

# %%
nfl_df_drop_spread.isnull().sum()
# Out:
# schedule_date             0
# schedule_season           0
# schedule_week             0
# schedule_playoff          0
# team_home                 0
# score_home                0
# score_away                0
# team_away                 0
# team_favorite_id          0
# spread_favorite           0
# over_under_line          10
# stadium                   0
# stadium_neutral           0
# weather_temperature     595
# weather_wind_mph        595
# weather_humidity       4019
# weather_detail         7801
# dtype: int64

# %%
#drop remaining over_under_line
nfl_df_drop_over_under = nfl_df_drop_spread.dropna(subset = ['over_under_line'])

# %%
nfl_df_drop_over_under
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 350       1/14/1968             1967     Superbowl              True
# 538       1/12/1969             1968     Superbowl              True
# 727       1/11/1970             1969     Superbowl              True
# 916       1/17/1971             1970     Superbowl              True
# 1105      1/16/1972             1971     Superbowl              True
# ...             ...              ...           ...               ...
# 12792     11/1/2020             2020             8             False
# 12793     11/1/2020             2020             8             False
# 12794     11/1/2020             2020             8             False
# 12795     11/1/2020             2020             8             False
# 12796     11/2/2020             2020             8             False
#
#                  team_home  score_home  score_away             team_away  \
# 350      Green Bay Packers        33.0        14.0       Oakland Raiders
# 538        Baltimore Colts         7.0        16.0         New York Jets
# 727     Kansas City Chiefs        23.0         7.0     Minnesota Vikings
# 916        Baltimore Colts        16.0        13.0        Dallas Cowboys
# 1105        Dallas Cowboys        24.0         3.0        Miami Dolphins
# ...                    ...         ...         ...                   ...
# 12792   Kansas City Chiefs        35.0         9.0         New York Jets
# 12793       Miami Dolphins        28.0        17.0      Los Angeles Rams
# 12794  Philadelphia Eagles        23.0         9.0        Dallas Cowboys
# 12795     Seattle Seahawks        37.0        27.0   San Francisco 49ers
# 12796      New York Giants        23.0        25.0  Tampa Bay Buccaneers
#
#       team_favorite_id  spread_favorite over_under_line  \
# 350                 GB            -13.5              43
# 538                IND            -18.0              40
# 727                MIN            -12.0              39
# 916                IND             -2.5              36
# 1105               DAL             -6.0              34
# ...                ...              ...             ...
# 12792               KC            -19.5              49
# 12793              LAR             -3.5            45.5
# 12794              PHI            -11.5            42.5
# 12795              SEA             -3.0            53.5
# 12796               TB            -12.5              45
#
#                        stadium  stadium_neutral  weather_temperature  \
# 350                Orange Bowl             True                 60.0
# 538                Orange Bowl             True                 66.0
# 727             Tulane Stadium             True                 55.0
# 916                Orange Bowl             True                 59.0
# 1105            Tulane Stadium             True                 34.0
# ...                        ...              ...                  ...
# 12792        Arrowhead Stadium            False                  NaN
# 12793        Hard Rock Stadium            False                  NaN
# 12794  Lincoln Financial Field            False                  NaN
# 12795        CenturyLink Field            False                  NaN
# 12796          MetLife Stadium            False                  NaN
#
#        weather_wind_mph weather_humidity weather_detail
# 350                12.0               74            NaN
# 538                12.0               80            NaN
# 727                14.0               84            NaN
# 916                11.0               60            NaN
# 1105               18.0               40            NaN
# ...                 ...              ...            ...
# 12792               NaN              NaN            NaN
# 12793               NaN              NaN            NaN
# 12794               NaN              NaN            NaN
# 12795               NaN              NaN            NaN
# 12796               NaN              NaN            NaN
#
# [10308 rows x 17 columns]

# %%
nfl_df_drop_over_under.isnull().sum()
# Out:
# schedule_date             0
# schedule_season           0
# schedule_week             0
# schedule_playoff          0
# team_home                 0
# score_home                0
# score_away                0
# team_away                 0
# team_favorite_id          0
# spread_favorite           0
# over_under_line           0
# stadium                   0
# stadium_neutral           0
# weather_temperature     595
# weather_wind_mph        595
# weather_humidity       4019
# weather_detail         7791
# dtype: int64

# %%
#drop rows that don't have weather_temperature
nfl_df_drop_weather = nfl_df_drop_over_under.dropna(subset = ['weather_temperature'])

# %%
nfl_df_drop_weather
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 350       1/14/1968             1967     Superbowl              True
# 538       1/12/1969             1968     Superbowl              True
# 727       1/11/1970             1969     Superbowl              True
# 916       1/17/1971             1970     Superbowl              True
# 1105      1/16/1972             1971     Superbowl              True
# ...             ...              ...           ...               ...
# 12770    10/25/2020             2020             7             False
# 12771    10/25/2020             2020             7             False
# 12774    10/25/2020             2020             7             False
# 12778    10/25/2020             2020             7             False
# 12790     11/1/2020             2020             8             False
#
#                 team_home  score_home  score_away           team_away  \
# 350     Green Bay Packers        33.0        14.0     Oakland Raiders
# 538       Baltimore Colts         7.0        16.0       New York Jets
# 727    Kansas City Chiefs        23.0         7.0   Minnesota Vikings
# 916       Baltimore Colts        16.0        13.0      Dallas Cowboys
# 1105       Dallas Cowboys        24.0         3.0      Miami Dolphins
# ...                   ...         ...         ...                 ...
# 12770   Arizona Cardinals        37.0        34.0    Seattle Seahawks
# 12771     Atlanta Falcons        22.0        23.0       Detroit Lions
# 12774      Houston Texans        20.0        35.0   Green Bay Packers
# 12778  New Orleans Saints        27.0        24.0   Carolina Panthers
# 12790       Detroit Lions        21.0        41.0  Indianapolis Colts
#
#       team_favorite_id  spread_favorite over_under_line  \
# 350                 GB            -13.5              43
# 538                IND            -18.0              40
# 727                MIN            -12.0              39
# 916                IND             -2.5              36
# 1105               DAL             -6.0              34
# ...                ...              ...             ...
# 12770              SEA             -3.5              56
# 12771              ATL             -2.0              55
# 12774               GB             -3.0              57
# 12778               NO             -6.5              50
# 12790              IND             -3.0            49.5
#
#                              stadium  stadium_neutral  weather_temperature  \
# 350                      Orange Bowl             True                 60.0
# 538                      Orange Bowl             True                 66.0
# 727                   Tulane Stadium             True                 55.0
# 916                      Orange Bowl             True                 59.0
# 1105                  Tulane Stadium             True                 34.0
# ...                              ...              ...                  ...
# 12770  University of Phoenix Stadium            False                 72.0
# 12771          Mercedes-Benz Stadium            False                 72.0
# 12774                    NRG Stadium            False                 72.0
# 12778        Mercedes-Benz Superdome            False                 72.0
# 12790                     Ford Field            False                 72.0
#
#        weather_wind_mph weather_humidity weather_detail
# 350                12.0               74            NaN
# 538                12.0               80            NaN
# 727                14.0               84            NaN
# 916                11.0               60            NaN
# 1105               18.0               40            NaN
# ...                 ...              ...            ...
# 12770               0.0              NaN           DOME
# 12771               0.0              NaN           DOME
# 12774               0.0              NaN           DOME
# 12778               0.0              NaN           DOME
# 12790               0.0              NaN           DOME
#
# [9713 rows x 17 columns]

# %%
nfl_df_drop_weather.isnull().sum()
# Out:
# schedule_date             0
# schedule_season           0
# schedule_week             0
# schedule_playoff          0
# team_home                 0
# score_home                0
# score_away                0
# team_away                 0
# team_favorite_id          0
# spread_favorite           0
# over_under_line           0
# stadium                   0
# stadium_neutral           0
# weather_temperature       0
# weather_wind_mph          0
# weather_humidity       3424
# weather_detail         7196
# dtype: int64

# %%
nfl_df_clean = nfl_df_drop_weather

# %%
nfl_df_clean['team_home'].value_counts()
# Out:
# Minnesota Vikings       341
# New Orleans Saints      338
# Dallas Cowboys          334
# Atlanta Falcons         333
# New England Patriots    328
# Detroit Lions           327
# Seattle Seahawks        321
# Kansas City Chiefs      319
# Denver Broncos          319
# Green Bay Packers       318
# Philadelphia Eagles     318
# Pittsburgh Steelers     318
# San Francisco 49ers     318
# Chicago Bears           316
# Washington Redskins     316
# New York Giants         316
# Miami Dolphins          316
# Buffalo Bills           315
# Cincinnati Bengals      315
# Tampa Bay Buccaneers    314
# New York Jets           314
# Indianapolis Colts      302
# San Diego Chargers      299
# Cleveland Browns        290
# Oakland Raiders         217
# Arizona Cardinals       215
# Carolina Panthers       195
# Jacksonville Jaguars    193
# Baltimore Ravens        185
# St. Louis Rams          175
# Tennessee Titans        160
# Houston Texans          152
# Los Angeles Rams        150
# Houston Oilers          144
# Los Angeles Raiders      98
# St. Louis Cardinals      66
# Phoenix Cardinals        48
# Baltimore Colts          38
# Tennessee Oilers         16
# Los Angeles Chargers     16
# Name: team_home, dtype: int64

# %%
#merge team names
nfl_df_clean_home = nfl_df_clean.replace({"San Diego Chargers": "Los Angeles Chargers", 
                                          "Tennessee Oilers": "Tennessee Titans", 
                                          "Baltimore Colts": "Indianapolis Colts",
                                          "Phoenix Cardinals": "Arizona Cardinals",
                                          "St. Louis Cardinals": "Arizona Cardinals",
                                          "Los Angeles Raiders": "Las Vegas Raiders",
                                          "Los Angeles Rams": "St. Louis Rams",
                                          "Oakland Raiders": "Las Vegas Raiders",
                                          "Houston Oilers": "Tennessee Titans",
                                          "Washington Redskins": "Washington Football Team"
                                         })
nfl_df_clean_home['team_home'].value_counts()
# Out:
# Minnesota Vikings           341
# Indianapolis Colts          340
# New Orleans Saints          338
# Dallas Cowboys              334
# Atlanta Falcons             333
# Arizona Cardinals           329
# New England Patriots        328
# Detroit Lions               327
# St. Louis Rams              325
# Seattle Seahawks            321
# Tennessee Titans            320
# Kansas City Chiefs          319
# Denver Broncos              319
# Green Bay Packers           318
# San Francisco 49ers         318
# Pittsburgh Steelers         318
# Philadelphia Eagles         318
# New York Giants             316
# Chicago Bears               316
# Washington Football Team    316
# Miami Dolphins              316
# Los Angeles Chargers        315
# Cincinnati Bengals          315
# Buffalo Bills               315
# Las Vegas Raiders           315
# New York Jets               314
# Tampa Bay Buccaneers        314
# Cleveland Browns            290
# Carolina Panthers           195
# Jacksonville Jaguars        193
# Baltimore Ravens            185
# Houston Texans              152
# Name: team_home, dtype: int64

# %%
nfl_df_clean_home['team_favorite_id'].value_counts()
# Out:
# PIT     425
# NE      412
# DEN     405
# DAL     405
# SF      387
# GB      368
# MIN     367
# PHI     361
# MIA     342
# NO      339
# SEA     322
# NYG     320
# LAC     314
# KC      308
# WAS     307
# IND     306
# LAR     306
# ATL     302
# LVR     301
# TEN     298
# CHI     296
# BUF     290
# NYJ     277
# CIN     255
# DET     238
# TB      232
# ARI     215
# BAL     209
# CLE     197
# CAR     187
# JAX     158
# PICK    142
# HOU     122
# Name: team_favorite_id, dtype: int64

# %%
#replace truncated team id with full team name
nfl_df_clean_home = nfl_df_clean.replace({"PIT": "Pittsburgh Steelers",
                                          "NE": "New England Patriots",
                                          "DEN": "Denver Broncos",
                                          "DAL": "Dalas Cowboys",
                                          "SF": "San Francisco 49ers",
                                          "GB": "Green Bay Packers",
                                          "MIN": "Minnesota Vikings",
                                          "PHI": "Philadelphia Eagles",
                                          "MIA": "Miami Dolphins",
                                          "NO": "New Orleans Saints",
                                          "SEA": "Seattle Seahawks",
                                          "NYG": "New York Giants",
                                          "LAC": "Los Angeles Chargers",
                                          "KC": "Kansas City Chiefs",
                                          "WAS": "Washington Football Team",
                                          "IND": "Indianapolis Colts",
                                          "LAR": "Los Angeles Rams",
                                          "ATL": "Atlanta Falcons",
                                          "LVR": "Las Vegas Raiders",
                                          "TEN": "Tennessee Titans",
                                          "CHI": "Chicago Bears",
                                          "Buf": "Buffalo Bills",
                                          "NYJ": "New York Jets",
                                          "CIN": "Cincinnati Bengals",
                                          "DET": "Detroit Lions",
                                          "TB": "Tampa Bay Buccaneers",
                                          "ARI": "Arizona Cardinals",
                                          "BAL": "Baltimore Ravens",
                                          "CLE": "Cleveland Browns",
                                          "CAR": "Carolina Panthers",
                                          "JAX": "Jacksonville Jaguars",
                                          "HOU": "Houston Texans"
                                         })

# %%
#create total score column
nfl_df_clean_home['total_score'] = nfl_df_clean_home['score_home'] + nfl_df_clean_home['score_away']
nfl_df_clean_home
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 350       1/14/1968             1967     Superbowl              True
# 538       1/12/1969             1968     Superbowl              True
# 727       1/11/1970             1969     Superbowl              True
# 916       1/17/1971             1970     Superbowl              True
# 1105      1/16/1972             1971     Superbowl              True
# ...             ...              ...           ...               ...
# 12770    10/25/2020             2020             7             False
# 12771    10/25/2020             2020             7             False
# 12774    10/25/2020             2020             7             False
# 12778    10/25/2020             2020             7             False
# 12790     11/1/2020             2020             8             False
#
#                 team_home  score_home  score_away           team_away  \
# 350     Green Bay Packers        33.0        14.0     Oakland Raiders
# 538       Baltimore Colts         7.0        16.0       New York Jets
# 727    Kansas City Chiefs        23.0         7.0   Minnesota Vikings
# 916       Baltimore Colts        16.0        13.0      Dallas Cowboys
# 1105       Dallas Cowboys        24.0         3.0      Miami Dolphins
# ...                   ...         ...         ...                 ...
# 12770   Arizona Cardinals        37.0        34.0    Seattle Seahawks
# 12771     Atlanta Falcons        22.0        23.0       Detroit Lions
# 12774      Houston Texans        20.0        35.0   Green Bay Packers
# 12778  New Orleans Saints        27.0        24.0   Carolina Panthers
# 12790       Detroit Lions        21.0        41.0  Indianapolis Colts
#
#          team_favorite_id  spread_favorite over_under_line  \
# 350     Green Bay Packers            -13.5              43
# 538    Indianapolis Colts            -18.0              40
# 727     Minnesota Vikings            -12.0              39
# 916    Indianapolis Colts             -2.5              36
# 1105        Dalas Cowboys             -6.0              34
# ...                   ...              ...             ...
# 12770    Seattle Seahawks             -3.5              56
# 12771     Atlanta Falcons             -2.0              55
# 12774   Green Bay Packers             -3.0              57
# 12778  New Orleans Saints             -6.5              50
# 12790  Indianapolis Colts             -3.0            49.5
#
#                              stadium  stadium_neutral  weather_temperature  \
# 350                      Orange Bowl             True                 60.0
# 538                      Orange Bowl             True                 66.0
# 727                   Tulane Stadium             True                 55.0
# 916                      Orange Bowl             True                 59.0
# 1105                  Tulane Stadium             True                 34.0
# ...                              ...              ...                  ...
# 12770  University of Phoenix Stadium            False                 72.0
# 12771          Mercedes-Benz Stadium            False                 72.0
# 12774                    NRG Stadium            False                 72.0
# 12778        Mercedes-Benz Superdome            False                 72.0
# 12790                     Ford Field            False                 72.0
#
#        weather_wind_mph weather_humidity weather_detail  total_score
# 350                12.0               74            NaN         47.0
# 538                12.0               80            NaN         23.0
# 727                14.0               84            NaN         30.0
# 916                11.0               60            NaN         29.0
# 1105               18.0               40            NaN         27.0
# ...                 ...              ...            ...          ...
# 12770               0.0              NaN           DOME         71.0
# 12771               0.0              NaN           DOME         45.0
# 12774               0.0              NaN           DOME         55.0
# 12778               0.0              NaN           DOME         51.0
# 12790               0.0              NaN           DOME         62.0
#
# [9713 rows x 18 columns]

# %%
nfl_df_clean_home.dtypes
# Out:
# schedule_date           object
# schedule_season          int64
# schedule_week           object
# schedule_playoff          bool
# team_home               object
# score_home             float64
# score_away             float64
# team_away               object
# team_favorite_id        object
# spread_favorite        float64
# over_under_line         object
# stadium                 object
# stadium_neutral           bool
# weather_temperature    float64
# weather_wind_mph       float64
# weather_humidity        object
# weather_detail          object
# total_score            float64
# dtype: object

# %%
#change over_under_line column to a float dtype
nfl_df_clean_home['over_under_line'] = pd.to_numeric(nfl_df_clean_home['over_under_line'],errors='coerce')

# %%
#calc games taht were over or under total score and add new column
for index, row in nfl_df_clean_home.iterrows():
    total = row[17]
    line = row[10]
    if total > line:
        nfl_df_clean_home.loc[index,'over_under'] = 'over'
    elif total < line:
        nfl_df_clean_home.loc[index,'over_under'] = 'under'
    else:
        nfl_df_clean_home.loc[index,'over_under'] = 'push'

nfl_df_clean_home
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 350       1/14/1968             1967     Superbowl              True
# 538       1/12/1969             1968     Superbowl              True
# 727       1/11/1970             1969     Superbowl              True
# 916       1/17/1971             1970     Superbowl              True
# 1105      1/16/1972             1971     Superbowl              True
# ...             ...              ...           ...               ...
# 12770    10/25/2020             2020             7             False
# 12771    10/25/2020             2020             7             False
# 12774    10/25/2020             2020             7             False
# 12778    10/25/2020             2020             7             False
# 12790     11/1/2020             2020             8             False
#
#                 team_home  score_home  score_away           team_away  \
# 350     Green Bay Packers        33.0        14.0     Oakland Raiders
# 538       Baltimore Colts         7.0        16.0       New York Jets
# 727    Kansas City Chiefs        23.0         7.0   Minnesota Vikings
# 916       Baltimore Colts        16.0        13.0      Dallas Cowboys
# 1105       Dallas Cowboys        24.0         3.0      Miami Dolphins
# ...                   ...         ...         ...                 ...
# 12770   Arizona Cardinals        37.0        34.0    Seattle Seahawks
# 12771     Atlanta Falcons        22.0        23.0       Detroit Lions
# 12774      Houston Texans        20.0        35.0   Green Bay Packers
# 12778  New Orleans Saints        27.0        24.0   Carolina Panthers
# 12790       Detroit Lions        21.0        41.0  Indianapolis Colts
#
#          team_favorite_id  spread_favorite  over_under_line  \
# 350     Green Bay Packers            -13.5             43.0
# 538    Indianapolis Colts            -18.0             40.0
# 727     Minnesota Vikings            -12.0             39.0
# 916    Indianapolis Colts             -2.5             36.0
# 1105        Dalas Cowboys             -6.0             34.0
# ...                   ...              ...              ...
# 12770    Seattle Seahawks             -3.5             56.0
# 12771     Atlanta Falcons             -2.0             55.0
# 12774   Green Bay Packers             -3.0             57.0
# 12778  New Orleans Saints             -6.5             50.0
# 12790  Indianapolis Colts             -3.0             49.5
#
#                              stadium  stadium_neutral  weather_temperature  \
# 350                      Orange Bowl             True                 60.0
# 538                      Orange Bowl             True                 66.0
# 727                   Tulane Stadium             True                 55.0
# 916                      Orange Bowl             True                 59.0
# 1105                  Tulane Stadium             True                 34.0
# ...                              ...              ...                  ...
# 12770  University of Phoenix Stadium            False                 72.0
# 12771          Mercedes-Benz Stadium            False                 72.0
# 12774                    NRG Stadium            False                 72.0
# 12778        Mercedes-Benz Superdome            False                 72.0
# 12790                     Ford Field            False                 72.0
#
#        weather_wind_mph weather_humidity weather_detail  total_score  \
# 350                12.0               74            NaN         47.0
# 538                12.0               80            NaN         23.0
# 727                14.0               84            NaN         30.0
# 916                11.0               60            NaN         29.0
# 1105               18.0               40            NaN         27.0
# ...                 ...              ...            ...          ...
# 12770               0.0              NaN           DOME         71.0
# 12771               0.0              NaN           DOME         45.0
# 12774               0.0              NaN           DOME         55.0
# 12778               0.0              NaN           DOME         51.0
# 12790               0.0              NaN           DOME         62.0
#
#       over_under
# 350         over
# 538        under
# 727        under
# 916        under
# 1105       under
# ...          ...
# 12770       over
# 12771      under
# 12774      under
# 12778       over
# 12790       over
#
# [9713 rows x 19 columns]

# %%
#calc performance against the spread
for index, row in nfl_df_clean_home.iterrows():
    home_team = row[4]
    away_team = row[7]
    fav_team = row[8]
    home_score = row[5]
    away_score = row[6]
    spread = row[9]
    if home_team == fav_team:
        fav_score = home_score + spread
        diff = fav_score - away_score
    elif away_team == fav_team:
        fav_score = away_score + spread
        diff = fav_score - home_score
    
    nfl_df_clean_home.loc[index,'spread_diff'] = diff
    if diff > 0:
        nfl_df_clean_home.loc[index,'cover'] = 'yes'
    elif diff < 0:
        nfl_df_clean_home.loc[index,'cover'] = 'no'
    else:
        nfl_df_clean_home.loc[index,'cover'] = 'push'

# %%
nfl_df_clean_home
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 350       1/14/1968             1967     Superbowl              True
# 538       1/12/1969             1968     Superbowl              True
# 727       1/11/1970             1969     Superbowl              True
# 916       1/17/1971             1970     Superbowl              True
# 1105      1/16/1972             1971     Superbowl              True
# ...             ...              ...           ...               ...
# 12770    10/25/2020             2020             7             False
# 12771    10/25/2020             2020             7             False
# 12774    10/25/2020             2020             7             False
# 12778    10/25/2020             2020             7             False
# 12790     11/1/2020             2020             8             False
#
#                 team_home  score_home  score_away           team_away  \
# 350     Green Bay Packers        33.0        14.0     Oakland Raiders
# 538       Baltimore Colts         7.0        16.0       New York Jets
# 727    Kansas City Chiefs        23.0         7.0   Minnesota Vikings
# 916       Baltimore Colts        16.0        13.0      Dallas Cowboys
# 1105       Dallas Cowboys        24.0         3.0      Miami Dolphins
# ...                   ...         ...         ...                 ...
# 12770   Arizona Cardinals        37.0        34.0    Seattle Seahawks
# 12771     Atlanta Falcons        22.0        23.0       Detroit Lions
# 12774      Houston Texans        20.0        35.0   Green Bay Packers
# 12778  New Orleans Saints        27.0        24.0   Carolina Panthers
# 12790       Detroit Lions        21.0        41.0  Indianapolis Colts
#
#          team_favorite_id  spread_favorite  ...  \
# 350     Green Bay Packers            -13.5  ...
# 538    Indianapolis Colts            -18.0  ...
# 727     Minnesota Vikings            -12.0  ...
# 916    Indianapolis Colts             -2.5  ...
# 1105        Dalas Cowboys             -6.0  ...
# ...                   ...              ...  ...
# 12770    Seattle Seahawks             -3.5  ...
# 12771     Atlanta Falcons             -2.0  ...
# 12774   Green Bay Packers             -3.0  ...
# 12778  New Orleans Saints             -6.5  ...
# 12790  Indianapolis Colts             -3.0  ...
#
#                              stadium stadium_neutral  weather_temperature  \
# 350                      Orange Bowl            True                 60.0
# 538                      Orange Bowl            True                 66.0
# 727                   Tulane Stadium            True                 55.0
# 916                      Orange Bowl            True                 59.0
# 1105                  Tulane Stadium            True                 34.0
# ...                              ...             ...                  ...
# 12770  University of Phoenix Stadium           False                 72.0
# 12771          Mercedes-Benz Stadium           False                 72.0
# 12774                    NRG Stadium           False                 72.0
# 12778        Mercedes-Benz Superdome           False                 72.0
# 12790                     Ford Field           False                 72.0
#
#        weather_wind_mph  weather_humidity weather_detail total_score  \
# 350                12.0                74            NaN        47.0
# 538                12.0                80            NaN        23.0
# 727                14.0                84            NaN        30.0
# 916                11.0                60            NaN        29.0
# 1105               18.0                40            NaN        27.0
# ...                 ...               ...            ...         ...
# 12770               0.0               NaN           DOME        71.0
# 12771               0.0               NaN           DOME        45.0
# 12774               0.0               NaN           DOME        55.0
# 12778               0.0               NaN           DOME        51.0
# 12790               0.0               NaN           DOME        62.0
#
#        over_under spread_diff  cover
# 350          over         5.5    yes
# 538         under         5.5    yes
# 727         under       -28.0     no
# 916         under       -28.0     no
# 1105        under       -28.0     no
# ...           ...         ...    ...
# 12770        over        -6.5     no
# 12771       under        -3.0     no
# 12774       under        12.0    yes
# 12778        over        -3.5     no
# 12790        over        17.0    yes
#
# [9713 rows x 21 columns]

# %%
#remove games before the 1979 season
nfl_df_1979_bool = nfl_df_clean_home.loc[:,'schedule_season']>=1979
nfl_df_1979 = nfl_df_clean_home[nfl_df_1979_bool]
nfl_df_1979
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 12770    10/25/2020             2020             7             False
# 12771    10/25/2020             2020             7             False
# 12774    10/25/2020             2020             7             False
# 12778    10/25/2020             2020             7             False
# 12790     11/1/2020             2020             8             False
#
#                   team_home  score_home  score_away           team_away  \
# 2501   Tampa Bay Buccaneers        31.0        16.0       Detroit Lions
# 2502          Buffalo Bills         7.0         9.0      Miami Dolphins
# 2503          Chicago Bears         6.0         3.0   Green Bay Packers
# 2504         Denver Broncos        10.0         0.0  Cincinnati Bengals
# 2505     Kansas City Chiefs        14.0         0.0     Baltimore Colts
# ...                     ...         ...         ...                 ...
# 12770     Arizona Cardinals        37.0        34.0    Seattle Seahawks
# 12771       Atlanta Falcons        22.0        23.0       Detroit Lions
# 12774        Houston Texans        20.0        35.0   Green Bay Packers
# 12778    New Orleans Saints        27.0        24.0   Carolina Panthers
# 12790         Detroit Lions        21.0        41.0  Indianapolis Colts
#
#            team_favorite_id  spread_favorite  ...  \
# 2501   Tampa Bay Buccaneers             -3.0  ...
# 2502         Miami Dolphins             -5.0  ...
# 2503          Chicago Bears             -3.0  ...
# 2504         Denver Broncos             -3.0  ...
# 2505     Kansas City Chiefs             -1.0  ...
# ...                     ...              ...  ...
# 12770      Seattle Seahawks             -3.5  ...
# 12771       Atlanta Falcons             -2.0  ...
# 12774     Green Bay Packers             -3.0  ...
# 12778    New Orleans Saints             -6.5  ...
# 12790    Indianapolis Colts             -3.0  ...
#
#                              stadium stadium_neutral  weather_temperature  \
# 2501              Houlihan's Stadium           False                 79.0
# 2502            Ralph Wilson Stadium           False                 74.0
# 2503                   Soldier Field           False                 78.0
# 2504               Mile High Stadium           False                 69.0
# 2505               Arrowhead Stadium           False                 76.0
# ...                              ...             ...                  ...
# 12770  University of Phoenix Stadium           False                 72.0
# 12771          Mercedes-Benz Stadium           False                 72.0
# 12774                    NRG Stadium           False                 72.0
# 12778        Mercedes-Benz Superdome           False                 72.0
# 12790                     Ford Field           False                 72.0
#
#        weather_wind_mph  weather_humidity weather_detail total_score  \
# 2501                9.0                87            NaN        47.0
# 2502               15.0                74            NaN        16.0
# 2503               11.0                68            NaN         9.0
# 2504                6.0                38            NaN        10.0
# 2505                8.0                71            NaN        14.0
# ...                 ...               ...            ...         ...
# 12770               0.0               NaN           DOME        71.0
# 12771               0.0               NaN           DOME        45.0
# 12774               0.0               NaN           DOME        55.0
# 12778               0.0               NaN           DOME        51.0
# 12790               0.0               NaN           DOME        62.0
#
#        over_under spread_diff  cover
# 2501         over        12.0    yes
# 2502        under        -3.0     no
# 2503        under         0.0   push
# 2504        under         7.0    yes
# 2505        under        13.0    yes
# ...           ...         ...    ...
# 12770        over        -6.5     no
# 12771       under        -3.0     no
# 12774       under        12.0    yes
# 12778        over        -3.5     no
# 12790        over        17.0    yes
#
# [9701 rows x 21 columns]

# %%
nfl_df_1979_absolute = nfl_df_1979['spread_diff'].abs()
nfl_df_1979
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 12770    10/25/2020             2020             7             False
# 12771    10/25/2020             2020             7             False
# 12774    10/25/2020             2020             7             False
# 12778    10/25/2020             2020             7             False
# 12790     11/1/2020             2020             8             False
#
#                   team_home  score_home  score_away           team_away  \
# 2501   Tampa Bay Buccaneers        31.0        16.0       Detroit Lions
# 2502          Buffalo Bills         7.0         9.0      Miami Dolphins
# 2503          Chicago Bears         6.0         3.0   Green Bay Packers
# 2504         Denver Broncos        10.0         0.0  Cincinnati Bengals
# 2505     Kansas City Chiefs        14.0         0.0     Baltimore Colts
# ...                     ...         ...         ...                 ...
# 12770     Arizona Cardinals        37.0        34.0    Seattle Seahawks
# 12771       Atlanta Falcons        22.0        23.0       Detroit Lions
# 12774        Houston Texans        20.0        35.0   Green Bay Packers
# 12778    New Orleans Saints        27.0        24.0   Carolina Panthers
# 12790         Detroit Lions        21.0        41.0  Indianapolis Colts
#
#            team_favorite_id  spread_favorite  ...  \
# 2501   Tampa Bay Buccaneers             -3.0  ...
# 2502         Miami Dolphins             -5.0  ...
# 2503          Chicago Bears             -3.0  ...
# 2504         Denver Broncos             -3.0  ...
# 2505     Kansas City Chiefs             -1.0  ...
# ...                     ...              ...  ...
# 12770      Seattle Seahawks             -3.5  ...
# 12771       Atlanta Falcons             -2.0  ...
# 12774     Green Bay Packers             -3.0  ...
# 12778    New Orleans Saints             -6.5  ...
# 12790    Indianapolis Colts             -3.0  ...
#
#                              stadium stadium_neutral  weather_temperature  \
# 2501              Houlihan's Stadium           False                 79.0
# 2502            Ralph Wilson Stadium           False                 74.0
# 2503                   Soldier Field           False                 78.0
# 2504               Mile High Stadium           False                 69.0
# 2505               Arrowhead Stadium           False                 76.0
# ...                              ...             ...                  ...
# 12770  University of Phoenix Stadium           False                 72.0
# 12771          Mercedes-Benz Stadium           False                 72.0
# 12774                    NRG Stadium           False                 72.0
# 12778        Mercedes-Benz Superdome           False                 72.0
# 12790                     Ford Field           False                 72.0
#
#        weather_wind_mph  weather_humidity weather_detail total_score  \
# 2501                9.0                87            NaN        47.0
# 2502               15.0                74            NaN        16.0
# 2503               11.0                68            NaN         9.0
# 2504                6.0                38            NaN        10.0
# 2505                8.0                71            NaN        14.0
# ...                 ...               ...            ...         ...
# 12770               0.0               NaN           DOME        71.0
# 12771               0.0               NaN           DOME        45.0
# 12774               0.0               NaN           DOME        55.0
# 12778               0.0               NaN           DOME        51.0
# 12790               0.0               NaN           DOME        62.0
#
#        over_under spread_diff  cover
# 2501         over        12.0    yes
# 2502        under        -3.0     no
# 2503        under         0.0   push
# 2504        under         7.0    yes
# 2505        under        13.0    yes
# ...           ...         ...    ...
# 12770        over        -6.5     no
# 12771       under        -3.0     no
# 12774       under        12.0    yes
# 12778        over        -3.5     no
# 12790        over        17.0    yes
#
# [9701 rows x 21 columns]

# %%
#create absolute value spread diff column
nfl_df_1979['spread_diff_absolute'] = nfl_df_1979['spread_diff'].abs()
nfl_df_1979
# Out:
# <ipython-input-31-bc921708245a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nfl_df_1979['spread_diff_absolute'] = nfl_df_1979['spread_diff'].abs()
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 12770    10/25/2020             2020             7             False
# 12771    10/25/2020             2020             7             False
# 12774    10/25/2020             2020             7             False
# 12778    10/25/2020             2020             7             False
# 12790     11/1/2020             2020             8             False
#
#                   team_home  score_home  score_away           team_away  \
# 2501   Tampa Bay Buccaneers        31.0        16.0       Detroit Lions
# 2502          Buffalo Bills         7.0         9.0      Miami Dolphins
# 2503          Chicago Bears         6.0         3.0   Green Bay Packers
# 2504         Denver Broncos        10.0         0.0  Cincinnati Bengals
# 2505     Kansas City Chiefs        14.0         0.0     Baltimore Colts
# ...                     ...         ...         ...                 ...
# 12770     Arizona Cardinals        37.0        34.0    Seattle Seahawks
# 12771       Atlanta Falcons        22.0        23.0       Detroit Lions
# 12774        Houston Texans        20.0        35.0   Green Bay Packers
# 12778    New Orleans Saints        27.0        24.0   Carolina Panthers
# 12790         Detroit Lions        21.0        41.0  Indianapolis Colts
#
#            team_favorite_id  spread_favorite  ...  stadium_neutral  \
# 2501   Tampa Bay Buccaneers             -3.0  ...            False
# 2502         Miami Dolphins             -5.0  ...            False
# 2503          Chicago Bears             -3.0  ...            False
# 2504         Denver Broncos             -3.0  ...            False
# 2505     Kansas City Chiefs             -1.0  ...            False
# ...                     ...              ...  ...              ...
# 12770      Seattle Seahawks             -3.5  ...            False
# 12771       Atlanta Falcons             -2.0  ...            False
# 12774     Green Bay Packers             -3.0  ...            False
# 12778    New Orleans Saints             -6.5  ...            False
# 12790    Indianapolis Colts             -3.0  ...            False
#
#       weather_temperature  weather_wind_mph  weather_humidity  weather_detail  \
# 2501                 79.0               9.0                87             NaN
# 2502                 74.0              15.0                74             NaN
# 2503                 78.0              11.0                68             NaN
# 2504                 69.0               6.0                38             NaN
# 2505                 76.0               8.0                71             NaN
# ...                   ...               ...               ...             ...
# 12770                72.0               0.0               NaN            DOME
# 12771                72.0               0.0               NaN            DOME
# 12774                72.0               0.0               NaN            DOME
# 12778                72.0               0.0               NaN            DOME
# 12790                72.0               0.0               NaN            DOME
#
#       total_score over_under  spread_diff cover  spread_diff_absolute
# 2501         47.0       over         12.0   yes                  12.0
# 2502         16.0      under         -3.0    no                   3.0
# 2503          9.0      under          0.0  push                   0.0
# 2504         10.0      under          7.0   yes                   7.0
# 2505         14.0      under         13.0   yes                  13.0
# ...           ...        ...          ...   ...                   ...
# 12770        71.0       over         -6.5    no                   6.5
# 12771        45.0      under         -3.0    no                   3.0
# 12774        55.0      under         12.0   yes                  12.0
# 12778        51.0       over         -3.5    no                   3.5
# 12790        62.0       over         17.0   yes                  17.0
#
# [9701 rows x 22 columns]

# %%
nfl_df_1979['game_score_diff_abs'] = (nfl_df_1979['score_home'] - nfl_df_1979['score_away']).abs()
nfl_df_1979
# Out:
# <ipython-input-32-8a91a87f6a6b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nfl_df_1979['game_score_diff_abs'] = (nfl_df_1979['score_home'] - nfl_df_1979['score_away']).abs()
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 12770    10/25/2020             2020             7             False
# 12771    10/25/2020             2020             7             False
# 12774    10/25/2020             2020             7             False
# 12778    10/25/2020             2020             7             False
# 12790     11/1/2020             2020             8             False
#
#                   team_home  score_home  score_away           team_away  \
# 2501   Tampa Bay Buccaneers        31.0        16.0       Detroit Lions
# 2502          Buffalo Bills         7.0         9.0      Miami Dolphins
# 2503          Chicago Bears         6.0         3.0   Green Bay Packers
# 2504         Denver Broncos        10.0         0.0  Cincinnati Bengals
# 2505     Kansas City Chiefs        14.0         0.0     Baltimore Colts
# ...                     ...         ...         ...                 ...
# 12770     Arizona Cardinals        37.0        34.0    Seattle Seahawks
# 12771       Atlanta Falcons        22.0        23.0       Detroit Lions
# 12774        Houston Texans        20.0        35.0   Green Bay Packers
# 12778    New Orleans Saints        27.0        24.0   Carolina Panthers
# 12790         Detroit Lions        21.0        41.0  Indianapolis Colts
#
#            team_favorite_id  spread_favorite  ...  weather_temperature  \
# 2501   Tampa Bay Buccaneers             -3.0  ...                 79.0
# 2502         Miami Dolphins             -5.0  ...                 74.0
# 2503          Chicago Bears             -3.0  ...                 78.0
# 2504         Denver Broncos             -3.0  ...                 69.0
# 2505     Kansas City Chiefs             -1.0  ...                 76.0
# ...                     ...              ...  ...                  ...
# 12770      Seattle Seahawks             -3.5  ...                 72.0
# 12771       Atlanta Falcons             -2.0  ...                 72.0
# 12774     Green Bay Packers             -3.0  ...                 72.0
# 12778    New Orleans Saints             -6.5  ...                 72.0
# 12790    Indianapolis Colts             -3.0  ...                 72.0
#
#       weather_wind_mph  weather_humidity  weather_detail  total_score  \
# 2501               9.0                87             NaN         47.0
# 2502              15.0                74             NaN         16.0
# 2503              11.0                68             NaN          9.0
# 2504               6.0                38             NaN         10.0
# 2505               8.0                71             NaN         14.0
# ...                ...               ...             ...          ...
# 12770              0.0               NaN            DOME         71.0
# 12771              0.0               NaN            DOME         45.0
# 12774              0.0               NaN            DOME         55.0
# 12778              0.0               NaN            DOME         51.0
# 12790              0.0               NaN            DOME         62.0
#
#       over_under spread_diff  cover spread_diff_absolute  game_score_diff_abs
# 2501        over        12.0    yes                 12.0                 15.0
# 2502       under        -3.0     no                  3.0                  2.0
# 2503       under         0.0   push                  0.0                  3.0
# 2504       under         7.0    yes                  7.0                 10.0
# 2505       under        13.0    yes                 13.0                 14.0
# ...          ...         ...    ...                  ...                  ...
# 12770       over        -6.5     no                  6.5                  3.0
# 12771      under        -3.0     no                  3.0                  1.0
# 12774      under        12.0    yes                 12.0                 15.0
# 12778       over        -3.5     no                  3.5                  3.0
# 12790       over        17.0    yes                 17.0                 20.0
#
# [9701 rows x 23 columns]

# %%
#copy the df so I can run some analysis on it but still have an original to reference if needed
nfl_df_analysis = nfl_df_1979
nfl_df_analysis
# Out:
#       schedule_date  schedule_season schedule_week  schedule_playoff  \
# 2501       9/1/1979             1979             1             False
# 2502       9/2/1979             1979             1             False
# 2503       9/2/1979             1979             1             False
# 2504       9/2/1979             1979             1             False
# 2505       9/2/1979             1979             1             False
# ...             ...              ...           ...               ...
# 12770    10/25/2020             2020             7             False
# 12771    10/25/2020             2020             7             False
# 12774    10/25/2020             2020             7             False
# 12778    10/25/2020             2020             7             False
# 12790     11/1/2020             2020             8             False
#
#                   team_home  score_home  score_away           team_away  \
# 2501   Tampa Bay Buccaneers        31.0        16.0       Detroit Lions
# 2502          Buffalo Bills         7.0         9.0      Miami Dolphins
# 2503          Chicago Bears         6.0         3.0   Green Bay Packers
# 2504         Denver Broncos        10.0         0.0  Cincinnati Bengals
# 2505     Kansas City Chiefs        14.0         0.0     Baltimore Colts
# ...                     ...         ...         ...                 ...
# 12770     Arizona Cardinals        37.0        34.0    Seattle Seahawks
# 12771       Atlanta Falcons        22.0        23.0       Detroit Lions
# 12774        Houston Texans        20.0        35.0   Green Bay Packers
# 12778    New Orleans Saints        27.0        24.0   Carolina Panthers
# 12790         Detroit Lions        21.0        41.0  Indianapolis Colts
#
#            team_favorite_id  spread_favorite  ...  weather_temperature  \
# 2501   Tampa Bay Buccaneers             -3.0  ...                 79.0
# 2502         Miami Dolphins             -5.0  ...                 74.0
# 2503          Chicago Bears             -3.0  ...                 78.0
# 2504         Denver Broncos             -3.0  ...                 69.0
# 2505     Kansas City Chiefs             -1.0  ...                 76.0
# ...                     ...              ...  ...                  ...
# 12770      Seattle Seahawks             -3.5  ...                 72.0
# 12771       Atlanta Falcons             -2.0  ...                 72.0
# 12774     Green Bay Packers             -3.0  ...                 72.0
# 12778    New Orleans Saints             -6.5  ...                 72.0
# 12790    Indianapolis Colts             -3.0  ...                 72.0
#
#       weather_wind_mph  weather_humidity  weather_detail  total_score  \
# 2501               9.0                87             NaN         47.0
# 2502              15.0                74             NaN         16.0
# 2503              11.0                68             NaN          9.0
# 2504               6.0                38             NaN         10.0
# 2505               8.0                71             NaN         14.0
# ...                ...               ...             ...          ...
# 12770              0.0               NaN            DOME         71.0
# 12771              0.0               NaN            DOME         45.0
# 12774              0.0               NaN            DOME         55.0
# 12778              0.0               NaN            DOME         51.0
# 12790              0.0               NaN            DOME         62.0
#
#       over_under spread_diff  cover spread_diff_absolute  game_score_diff_abs
# 2501        over        12.0    yes                 12.0                 15.0
# 2502       under        -3.0     no                  3.0                  2.0
# 2503       under         0.0   push                  0.0                  3.0
# 2504       under         7.0    yes                  7.0                 10.0
# 2505       under        13.0    yes                 13.0                 14.0
# ...          ...         ...    ...                  ...                  ...
# 12770       over        -6.5     no                  6.5                  3.0
# 12771      under        -3.0     no                  3.0                  1.0
# 12774      under        12.0    yes                 12.0                 15.0
# 12778       over        -3.5     no                  3.5                  3.0
# 12790       over        17.0    yes                 17.0                 20.0
#
# [9701 rows x 23 columns]

# %%
#save the clean version to a new csv file so I can do analysis
nfl_df_1979.to_csv("spreadspoke_scores_for_analysis.csv")
